# %%
# spell_database.ipynb

# Step 1: Import Libraries
import pandas as pd
from spell_database import load_spell_data, filter_spells

# Step 2: Load Spell Data
filepath = 'C:/Users/Andrew/Documents/AI Series/data/spell.jsonl'
spell_data = load_spell_data(filepath)

# Step 3: Display Initial Data
print("Initial Spell Data:")
display(spell_data.head())

# Step 4: Filter Example
# Example filter - Filter spells containing "fire" and of type "Fire Magic"
search_term = "fire"
spell_type = "Fire Magic"
filtered_spells = filter_spells(spell_data, search_term, spell_type)

# Display filtered spells
display(filtered_spells)

# Step 5: Export Filtered Spells to HTML
filtered_spells.to_html("filtered_spells.html", index=False)
print("Filtered spells have been exported to 'filtered_spells.html'")
# Out:
# Initial Spell Data:
#        spell_name         spell_type  \
# 0   Soul Abductor  Soul Corpse Magic
# 1       Skin Fort         Skin Magic
# 2  Scale Dominate        Scale Magic
# 3  Scale Regulate        Scale Magic
# 4   Rock Fortress         Rock Magic
#
#                                    spell_description
# 0  With an open grimoire, the user summons back a...
# 1  With an open grimoire, the user shapes and har...
# 2  With an open grimoireand purifieddevilpower, t...
# 3  With an open grimoire, the user manifests a sc...
# 4  With an open grimoire, the user creates a wall...
#                              spell_name  spell_type  \
# 341          Maximum Exploding Fireball  Fire Magic
# 421  Extreme Killing Vanishing Fireball  Fire Magic
# 424                  Exploding Fireball  Fire Magic
# 426                  Hellfire Incarnate  Fire Magic
#
#                                      spell_description
# 341  With an open grimoire, the user generates a la...
# ...
